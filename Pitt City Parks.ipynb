# %% [markdown]
# # City Parks in Pittburgh

# %% [markdown]
# One of the sub-metrics we depended on was healiest neighborhood in terms of exercise and getting outside. We decided to measure this but showing which neighborhood has the most public parks

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Park_Data=pd.read_csv('Pitt Park Data.csv')

# %%
Park_Names=(Park_Data['neighborhood'])

# %%
len(Park_Names.value_counts())
# Out:
# 73

# %% [markdown]
# There are 73 different neighborhoods that contain at least 1 public park

# %%
hood_data=Park_Data['neighborhood']

# %%
i_data=(Park_Data['neighborhood'].value_counts())

# %%
query_mask=i_data!=1

# %%
i_data.head(13).plot(kind='bar')

# %% [markdown]
# A bar graph of the top 13 neighborhods and the number of parks they have

# %%
hood_data.value_counts().head(13)
# Out:
# East Liberty                 12
# Central Business District    10
# Beechview                     8
# South Side Slopes             7
# Point Breeze                  7
# Squirrel Hill South           6
# Mount Washington              6
# Sheraden                      6
# Hazelwood                     6
# South Side Flats              6
# South Oakland                 5
# Troy Hill                     5
# Central Oakland               4
# Name: neighborhood, dtype: int64

# %%
i_data.tail(60).plot(kind='bar')

# %%
hood_data.value_counts().tail(60)
# Out:
# Brighton Heights            4
# Marshall-Shadeland          4
# Elliott                     4
# Manchester                  3
# Upper Lawrenceville         3
# Bloomfield                  3
# Spring Hill-City View       3
# Carrick                     3
# Crawford-Roberts            3
# Larimer                     3
# Lincoln-Lemington-Belmar    3
# Westwood                    3
# Garfield                    3
# Brookline                   3
# Beltzhoover                 3
# Point Breeze North          3
# Lower Lawrenceville         3
# Swisshelm Park              3
# Central Northside           3
# North Shore                 3
# Greenfield                  3
# Lincoln Place               2
# Terrace Village             2
# Highland Park               2
# Polish Hill                 2
# Perry North                 2
# West End                    2
# Duquesne Heights            2
# Fineview                    2
# Crafton Heights             2
# Allegheny Center            2
# ...

# %% [markdown]
# The bottom 60 neighborhoods and the numebr of parks they have. This is added to show that the bottom 60 neighborhood do not have lots of varities in the number of parks they have.

# %% [markdown]
# ## After analysis of the following dataset, it can be concluded that by the metric of healthiest neighborhood measured by the number of city parks East Liberty is the healthiest neighborhood in Pittsburgh.
